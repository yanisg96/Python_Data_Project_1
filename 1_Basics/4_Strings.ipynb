# %%
"This is a string in double quotes"
# Out:
# 'This is a string in double quotes'

# %%
'This is a string in single quotes'
# Out:
# 'This is a string in single quotes'

# %% [markdown]
# You have to use " or ' for strings

# %%
skill = 'Python'
type(skill)
# Out:
# str

# %%
skill.upper()
# Out:
# 'PYTHON'

# %% [markdown]
# by using .upper or .lower (which are called methods) after the variable skill, you can change it all to uppercase or lowercase letters

# %%
skill.lower()
# Out:
# 'python'

# %% [markdown]
# You can see all the methods that can be used on the variables per type etc, by using help(str)

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
"Python".lower()
# Out:
# 'python'

# %%
str.lower("Python")
# Out:
# 'python'

# %% [markdown]
# str --> class
#
# lower --> method
#
# "Python" --> instance of 'str' class

# %%
skill = "Python"

# %%
skill.lower()
# Out:
# 'python'

# %%
skill.replace("P","J")
# Out:
# 'Jython'

# %% [markdown]
# to use the method .replace(), you have to enter in the () the 'old term', the 'new term' or replacement and 'count' which has a default value of -1.
#
# If you don't need to input count, and will use the default value, you don't have to especify it or include it.

# %%
job_title = "Data Analyst" # rename Data as Doto

# %% [markdown]
# This was my way of doing it:
#
# job_title.replace("Data", "Doto")
#
# Next is the way you can also use the count (old, new, count) and the example used in the course

# %%
job_title = job_title.replace('a', 'o', 2)

# %%
job_title
# Out:
# 'Doto Analyst'

# %%
job_title.split(sep= " ", maxsplit=1)
# Out:
# ['Doto', 'Analyst']

# %%
str.__add__("Data", " Analyst")
# Out:
# 'Data Analyst'

# %%
"Data".__add__(" Analyst")
# Out:
# 'Data Analyst'

# %%
"Data" + " Analyst"
# Out:
# 'Data Analyst'

# %%
"Data Analyst" * 10
# Out:
# 'Data AnalystData AnalystData AnalystData AnalystData AnalystData AnalystData AnalystData AnalystData AnalystData Analyst'

# %%
"Data Analyst".__len__()
# Out:
# 12

# %%
len("Data Analyst")
# Out:
# 12
