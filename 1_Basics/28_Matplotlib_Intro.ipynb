# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# From the matplotlib github
#
# https://github.com/matplotlib/matplotlib/blob/main/lib/matplotlib/pyplot.py

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
