# %% [markdown]
# ## Conditional Statements

# %% [markdown]
# **if** - First condition check - First condition to be evaluated - Executes block if condition is true
#
# **elif** - Subsequent condition check - Next condition, if *if* is false - Executes block if this condition is true
#
# **else** - Fallback if no conditions are met - Executes block if all above conditions are false

# %%
if True:
  print("What's up Data Nerds")
# Out:
# What's up Data Nerds

# %%
if False:
  print("What's up Data Nerds")

# %%
# Skill required for job posting
job_skill = 'SQL'

# Applicant skill
applicant_skill = 'SQL'

# %%
if job_skill == applicant_skill:
  print('Skills Match!')
# Out:
# Skills Match!

# %%
years_experience = 3
applicant_skill = 'Python'
job_skill = 'SQL'

if job_skill == applicant_skill:
  print('Skills Match!')
elif years_experience >= 5:
  print('Enough Experience; No SQL')
elif applicant_skill == 'Python':
  print('This applicant should know SQL')
else:
  print('No Skill or Experience')
# Out:
# This applicant should know SQL

# %%
years_experience = 3
applicant_skill = 'Python'
job_skill = 'SQL'

if job_skill == applicant_skill:
  print('Skills Match!')
elif years_experience >= 5:
  print('Enough Experience; No SQL')
elif applicant_skill == 'Python':
  pass
else:
  print('No Skill or Experience')

# %%
# pass is used in case you don't know what to put in there yet,
# and to avoid the syntax error
if job_skill == applicant_skill:
  pass
