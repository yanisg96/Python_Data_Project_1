# %%
# create a list of 1,000,000 salaries ranging from 50,000 to 150,000
import random

salary_list = [random.randint(50000,100000) for _ in range(10_000_000)]

# %%
import statistics

# %%
# %%timeit

statistics.median(salary_list)
# Out:
# 5.3 s ± 356 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.median(salary_list)
# Out:
# 673 ms ± 9.88 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
my_array = np.array([1, 2, 3, 4])

# %%
my_array.mean()
# Out:
# 2.5

# %% [markdown]
# ## Practical Example

# %%
import numpy as np

# %%
# np.nan where nan means 'not a number' and is a float type
# specifically for numerical data

# %%
# Job titles
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])

# Base salaries
base_salaries = np.array([60000, 80000, 75000, 90000, np.nan])

# Bonus rates
bonus_rates = np.array([.05, .1, .08, .12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
# nanmean is used when nan is being used due to not knowing one of the values
np.nanmean(total_salaries)
# Out:
# 83200.0
